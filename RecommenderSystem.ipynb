# %%
import pandas as pd
data = pd.read_csv('tmdb_5000_movies.csv')
data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
data_df = data[['original_title','genres','keywords']]
data_df
# Out:
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
import json
inputs = data_df['original_title']
label = data_df['genres']
label=json.loads(label[0])
label
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
labels = (''.join(jj['name'].split()) for jj in label)
print(labels)
# Out:
# <generator object <genexpr> at 0x0000019DDEB17060>

# %%
label = ' '.join(''.join(jj['name'].split()) for jj in label)
label
# Out:
# 'Action Adventure Fantasy ScienceFiction'

# %%
def genras_and_keywords_to_string(row):
    genres = json.loads(row['genres'])
    genres = ' '.join(''.join(j['name'].split()) for j in genres)

    keywords = json.loads(row['keywords'])
    keywords = ' '.join(''.join(i['name'].split())for i in keywords)
    return f'{genres} {keywords}'

# %%
data['string'] = data.apply(genras_and_keywords_to_string, axis=1)

# %%
data['string']
# Out:
# 0       Action Adventure Fantasy ScienceFiction cultur...
# 1       Adventure Fantasy Action ocean drugabuse exoti...
# 2       Action Adventure Crime spy basedonnovel secret...
# 3       Action Crime Drama Thriller dccomics crimefigh...
# 4       Action Adventure ScienceFiction basedonnovel m...
#                               ...
# 4798    Action Crime Thriller unitedstates–mexicobarri...
# 4799                                      Comedy Romance
# 4800    Comedy Drama Romance TVMovie date loveatfirsts...
# 4801
# 4802      Documentary obsession camcorder crush dreamgirl
# Name: string, Length: 4803, dtype: object

# %%
inputs = data['original_title']
labels = data['string']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=2000)  # keeps the top 2000 frequent words in the corpus

# %%
X = tfidf.fit_transform(labels)  # 因只會推薦已有的資料, 所以不用切分成 train, test

# %%
movie2idx = pd.Series(data.index, index=data['title'])
# 將原本 data 的 index 作為值, title 作為 index, 可以用名稱搜尋到 index
movie2idx
# Out:
# title
# Avatar                                         0
# Pirates of the Caribbean: At World's End       1
# Spectre                                        2
# The Dark Knight Rises                          3
# John Carter                                    4
#                                             ...
# El Mariachi                                 4798
# Newlyweds                                   4799
# Signed, Sealed, Delivered                   4800
# Shanghai Calling                            4801
# My Date with Drew                           4802
# Length: 4803, dtype: int64

# %%
idx = movie2idx['Avatar']  # 找出所要資料的 index
idx
# Out:
# 0

# %%
query = X[idx]
query
# Out:
# <1x2000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 21 stored elements in Compressed Sparse Row format>

# %%
query.toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
scores = cosine_similarity(query, X)
# compute consine similarity between query and every vector in X

# %%
# 因為為 1*2000 的陣列, 可以轉變成 1 維陣列
scores = scores.flatten()

# %%
import matplotlib.pyplot as plt
plt.plot(scores)

# %%
decend = (-scores).argsort()
# We don't want sort because we don't care about the score itself
# rather we care about argsort which tells us which movie it goes in if we use argsort

# %%
plt.plot(scores[decend])

# %%
recommended_idx = decend[1:6] # start from because we don't want to recommand the movie itself

# %%
# convert back to get title
data['title'].iloc[recommended_idx]
# Out:
# 47      Star Trek Into Darkness
# 3214                 Barbarella
# 1287         A Monster in Paris
# 61            Jupiter Ascending
# 3730                      Cargo
# Name: title, dtype: object

# %%
def recommand(title):
    # get the row in the dataframe for this movie
    idx = movie2idx[title]
    if type(idx) == pd.Series: # if the movie title is the same for mutiple rows, it will return a pandas.Series rather than index
        idx = idx.iloc[0] # we grep the first item instead
    query = X[idx]
    scores = cosine_similarity(query, X)

    scores = scores.flatten()
    recommended_idx = (-scores).argsort()[1:6]

    return data['title'].iloc[recommended_idx]

# %%
print('Recommendtions for "Avatar" :')
print(recommand('Avatar'))
# Out:
# Recommendtions for "Avatar" :
# 47      Star Trek Into Darkness
# 3214                 Barbarella
# 1287         A Monster in Paris
# 61            Jupiter Ascending
# 3730                      Cargo
# Name: title, dtype: object

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfTransformer
import json
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances



class Recommender:
    def __init__(self):
        self.tfidf = TfidfTransformer()
    def read_csv(self):
        df = pd.read_csv(r'C:\python\NLP_machine-learning\tmdb_5000_movies.csv')
        return df
    def genras_and_keywords_to_string(self,row):
        df = self.read_csv()
        genres = json.loads(row['genres'])
        genres = ' '.join(''.join(j['name'].split()) for j in genres)

        keywords = json.loads(row['keywords'])
        keywords = ' '.join(''.join(i['name'].split())for i in keywords)
        return f'{genres} {keywords}'
    def apply_to_string_func(self):
        df = self.read_csv()
        df['string'] = df.apply(self.genras_and_keywords_to_string, axis=1)
        labels = df['string']
        return labels
    def tf_idf(self):
        labels = self.apply_to_string_func()
        tfidf = self.tfidf(max_featrures = 2000)
        X = tfidf.fit_transform(labels)
        return X
    def movie2idx(self):
        df = self.read_csv()
        movie_to_idx = pd.Series(df.index, index=df['title'])
        return movie_to_idx
    def recommand(self,title):
        # get the row in the dataframe for this movie
        df = self.read_csv()
        movie2idx = self.movie2idx()
        idx = movie2idx[title]
        X = self.tf_idf()
        if type(idx) == pd.Series: # if the movie title is the same for mutiple rows, it will return a pandas.Series rather than index
            idx = idx.iloc[0] # we grep the first item instead
        query = X[idx]
        scores = cosine_similarity(query, X)

        scores = scores.flatten()
        recommended_idx = (-scores).argsort()[1:6]

        return df['title'].iloc[recommended_idx]

recommand = Recommender()
movie = input('Please input a Movie name :')
print(f'Recommendtions for {movie} :')
print(recommand.recommand(movie))
# Out:
# Recommendtions for Avatar :
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\python\NLP_machine-learning\RecommenderSystem.ipynb Cell 26 in <cell line: 55>()
#      <a href='vscode-notebook-cell:/c%3A/python/NLP_machine-learning/RecommenderSystem.ipynb#X45sZmlsZQ%3D%3D?line=52'>53</a> movie = input('Please input a Movie name :')
#      <a href='vscode-notebook-cell:/c%3A/python/NLP_machine-learning/RecommenderSystem.ipynb#X45sZmlsZQ%3D%3D?line=53'>54</a> print(f'Recommendtions for {movie} :')
# ---> <a href='vscode-notebook-cell:/c%3A/python/NLP_machine-learning/RecommenderSystem.ipynb#X45sZmlsZQ%3D%3D?line=54'>55</a> print(recommand.recommand(movie))
#
# c:\python\NLP_machine-learning\RecommenderSystem.ipynb Cell 26 in Recommender.recommand(self, title)
# ...
